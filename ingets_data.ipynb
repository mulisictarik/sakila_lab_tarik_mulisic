# %% [markdown]
# ### Task 0

# %%
import duckdb
import pandas as pd
from pathlib import Path

duckdb_path = "data/sakila.duckdb"
Path(duckdb_path).unlink(missing_ok=True)

with duckdb.connect(duckdb_path) as conn, open("sql/load_sakila.sql") as ingest_script:
    conn.sql(ingest_script.read())

    description = conn.sql("DESC;").df()
    films = conn.sql("FROM film;").df()

films.head(3)
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
#
#                                          description release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...         2006
# 1  A Astounding Epistle of a Database Administrat...         2006
# 2  A Astounding Reflection of a Lumberjack And a ...         2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                  <NA>                6         0.99      86
# 1            1                  <NA>                3         4.99      48
# 2            1                  <NA>                7         2.99      50
#
#    replacement_cost rating                  special_features  \
# 0             20.99     PG  Deleted Scenes,Behind the Scenes
# 1             12.99      G           Trailers,Deleted Scenes
# 2             18.99  NC-17           Trailers,Deleted Scenes
#
#           last_update
# 0 2021-03-06 15:52:00
# 1 2021-03-06 15:52:00
# 2 2021-03-06 15:52:00

# %%
description.head()
# Out:
#   database schema      name  \
# 0   sakila   main     actor
# 1   sakila   main   address
# 2   sakila   main  category
# 3   sakila   main      city
# 4   sakila   main   country
#
#                                         column_names  \
# 0     [actor_id, first_name, last_name, last_update]
# 1  [address_id, address, address2, district, city...
# 2                   [category_id, name, last_update]
# 3           [city_id, city, country_id, last_update]
# 4                 [country_id, country, last_update]
#
#                                         column_types  temporary
# 0              [DOUBLE, VARCHAR, VARCHAR, TIMESTAMP]      False
# 1  [BIGINT, VARCHAR, VARCHAR, VARCHAR, BIGINT, VA...      False
# 2                       [BIGINT, VARCHAR, TIMESTAMP]      False
# 3               [BIGINT, VARCHAR, BIGINT, TIMESTAMP]      False
# 4                       [BIGINT, VARCHAR, TIMESTAMP]      False

# %%
film.colums.
# Out:
#   Cell In[26], line 1
#     film.colums.
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Task 1

# %%
def query_sakila(query: str, duckdb_path="data/sakila.duckdb"):
    with duckdb.connect(duckdb_path) as conn:
        df = conn.sql(query=query).df()

        return df


query_sakila("""
                   SELECT title, length
                   FROM film
                   WHERE length > 180
                   ORDER BY length DESC;

""")
# Out:
#                  title  length
# 0         WORST BANGER     185
# 1        CHICAGO NORTH     185
# 2       CONTROL ANTHEM     185
# 3       DARN FORRESTER     185
# 4    SWEET BROTHERHOOD     185
# 5          GANGS PRIDE     185
# 6            HOME PITY     185
# 7   SOLDIERS EVOLUTION     185
# 8         POND SEATTLE     185
# 9        MUSCLE BRIGHT     185
# 10     MOONWALKER FOOL     184
# 11      THEORY MERMAID     184
# 12   CONSPIRACY SPIRIT     184
# 13    CRYSTAL BREAKING     184
# 14      SORORITY QUEEN     184
# 15      SONS INTERVIEW     184
# 16     SMOOCHY CONTROL     184
# 17      KING EVOLUTION     184
# 18      YOUNG LANGUAGE     183
# 19       SCALAWAG DUCK     183
# 20      FRONTIER CABIN     183
# 21       CATCH AMISTAD     183
# 22           WIFE TURN     183
# 23       MONSOON CAUSE     182
# 24       RECORDS ZORRO     182
# 25          REDS POCUS     182
# 26         SATURN NAME     182
# 27      SEARCHERS WAIT     182
# 28     BAKED CLEOPATRA     182
# 29       LOVE SUICIDES     181
# 30      LAWLESS VISION     181
# 31  RUNAWAY TENENBAUMS     181
# 32       JACKET FRISCO     181
# 33      INTRIGUE WORST     181
# 34     HOTEL HAPPINESS     181
# 35    HAUNTING PIANIST     181
# 36      STAR OPERATION     181
# 37         WILD APOLLO     181
# 38    ANALYZE HOOSIERS     181

# %%
query_sakila('SELECT title, rating, length, description FROM films WHERE LIKE 'love'
# Out:
# ---------------------------------------------------------------------------
# ParserException                           Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 query_sakila('actor')
#
# Cell In[22], line 2, in query_sakila(query, duckdb_path)
#       1 def query_sakila(query: str, duckdb_path="data/sakila.duckdb"):
# ----> 2     with duckdb.connect(duckdb_path) as conn:
#       3         df = conn.sql(query=query).df()
#       5         return df
#
# Cell In[22], line 3, in query_sakila(query, duckdb_path)
#       1 def query_sakila(query: str, duckdb_path="data/sakila.duckdb"):
#       2     with duckdb.connect(duckdb_path) as conn:
# ----> 3         df = conn.sql(query=query).df()
#       5         return df
#
# ParserException: Parser Error: syntax error at or near "actor"
#
# LINE 1: actor
#         ^
